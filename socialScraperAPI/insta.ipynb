# %%
import requests
import pandas as pd

url = "https://instagram-scraper-api2.p.rapidapi.com/v1.2/posts"

querystring = {"username_or_id_or_url":"mrbeast"}

headers = {
	"x-rapidapi-key": "04edcb85a3mshac913eab2bf3075p184839jsn4e30538b9195",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
#get last 10 post id
params={"limit": 10}
posts = response.json().get('posts', [])
last_10_post_ids = [post['id'] for post in posts[:10]]


print(response.json()['data'])
df=pd.DataFrame(response)
df
# Out:
# {'count': 12, 'items': [{'boost_unavailable_identifier': None, 'boost_unavailable_reason': None, 'boost_unavailable_reason_v2': None, 'can_modify_carousel': False, 'can_reply': False, 'can_reshare': True, 'can_save': True, 'caption': {'created_at': 1732824650, 'created_at_utc': 1732824650, 'did_report_as_spam': False, 'hashtags': [], 'id': '3511510130787749851', 'is_covered': False, 'is_ranked_comment': False, 'mentions': [], 'private_reply_status': 0, 'share_enabled': False, 'text': 'We are both dropping big videos together November 30th 👀', 'text_translation': 'We are both dropping big videos together November 30th 👀', 'type': 1, 'user': {'fbid_v2': 17841402202464771, 'full_name': 'MrBeast', 'id': '2278169415', 'is_private': False, 'is_unpublished': False, 'is_verified': True, 'profile_pic_id': '1765328607101572916', 'profile_pic_url': 'https://scontent-fra3-1.cdninstagram.com/v/t51.2885-19/31077884_211593632905749_1394765701385814016_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-fra3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=4EWS8DciaJMQ7kNvgHholcp&_nc_gid=798e236958b84a3e90de0a90a16e0110&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYDPA4UfIaOYsv6X6CtMh5CvIjwU-Mu81vLOmfNhguXETg&oe=67798B4F&_nc_sid=b41fef', 'username': 'mrbeast'}, 'user_id': '2278169415'}, 'caption_is_edited': False, 'carousel_media': [{'carousel_parent_id': '3511510130787749851_2278169415', 'commerciality_status': 'not_commercial', 'explore_pivot_grid': False, 'fb_user_tags': {'in': []}, 'featured_products': [], 'id': '3511510122801906360', 'image_versions': {'items': [{'height': 1800, 'url': 'https://scontent-fra3-1.cdninstagram.com/v/t51.29350-15/468618718_1105623314294222_3860806756476331846_n.jpg?se=7&stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-fra3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=zbtn94fEOK0Q7kNvgEn-QxT&_nc_gid=798e236958b84a3e90de0a90a16e0110&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzUxMTUxMDEyMjgwMTkwNjM2MA%3D%3D.3-ccb7-5&oh=00_AYD5DznNHyyTxROtRQ865UT14gLKblxqmbe58wpWuUZAgw&oe=67798412&_nc_sid=b41fef', 'width': 1440}, {'height': 600, 'url': 'https://scontent-fra3-1.cdninstagram.com/v/t51.29350-15/468618718_1105623314294222_3860806756476331846_n.jpg?stp=dst-jpg_e35_p480x480_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-fra3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=zbtn94fEOK0Q7kNvgEn-QxT&_nc_gid=798e236958b84a3e90de0a90a16e0110&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzUxMTUxMDEyMjgwMTkwNjM2MA%3D%3D.3-ccb7-5&oh=00_AYC8xeojwsyqZuEkII1NqJEOJUth3gD0Xg-V34OumZVSOA&oe=67798412&_nc_sid=b41fef', 'width': 480}]}, 'is_video': False, 'location': None, 'media_name': 'album_item', 'media_type': 1, 'original_height': 1800, 'original_width': 1440, 'product_suggestions': [], 'product_type': 'carousel_item', 'sharing_friction_info': {'bloks_app_url': None, 'sharing_friction_payload': None, 'should_have_sharing_friction': False}, 'shop_routing_user_id': None, 'sponsor_tags': [], 'tagged_users': [{'position': [0.6791277259, 0.453271028], 'show_category_of_user': False, 'user': {'full_name': 'Cristiano Ronaldo', 'id': '173560420', 'is_private': False, 'is_verified': True, 'profile_pic_id': '2821570366679261765', 'profile_pic_url': 'https://scontent-fra3-1.cdninstagram.com/v/t51.2885-19/278931269_360124899498969_9006978846103417088_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-fra3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=5d8jJnmZvZEQ7kNvgEXBxb4&_nc_gid=798e236958b84a3e90de0a90a16e0110&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAHWKmNxZazASCxpy-zaJ12SGsfPi2JwARMnVhn4aWyew&oe=67799E4E&_nc_sid=b41fef', 'username': 'cristiano'}, 'x': 0.6791277259, 'y': 0.453271028}], 'taken_at': 1732824648, 'taken_at_ts': 1732824648, 'thumbnail_url': 'https://scontent-fra3-1.cdninstagram.com/v/t51.29350-15/468618718_1105623314294222_3860806756476331846_n.jpg?se=7&stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdl ...
#                                                       0
# 0     b'{"data":{"count":12,"items":[{"boost_unavail...
# 1     b'null,"can_modify_carousel":false,"can_reply"...
# 2     b'd_at_utc":1732824650,"did_report_as_spam":fa...
# 3     b'false,"mentions":[],"private_reply_status":0...
# 4     b'h \xf0\x9f\x91\x80","text_translation":"We a...
# ...                                                 ...
# 2328  b'profile_pic_url":"https://scontent-fra3-1.cd...
# 2329  b'dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-fra3...
# 2330  b'3e90de0a90a16e0110&edm=ABmJApABAAAA&ccb=7-5&...
# 2331  b'ername":"mrbeast"}},"pagination_token":"Ik1I...
# 2332  b'SBEbBh4ZFWUrVwhbAR0RAFsxRj5EHFIBWUZtXi1JRhVT...
#
# [2333 rows x 1 columns]

# %%
import requests

url = "https://instagram-scraper-api2.p.rapidapi.com/v1.2/posts"

querystring = {"username_or_id_or_url":"mrbeast"}

headers = {
	"x-rapidapi-key": "04edcb85a3mshac913eab2bf3075p184839jsn4e30538b9195",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
df1 = pd.DataFrame(response)
df1
# Out:
# {'data': {'count': 12, 'items': [{'boost_unavailable_identifier': None, 'boost_unavailable_reason': None, 'boost_unavailable_reason_v2': None, 'can_modify_carousel': False, 'can_reply': False, 'can_reshare': True, 'can_save': True, 'caption': {'created_at': 1732824650, 'created_at_utc': 1732824650, 'did_report_as_spam': False, 'hashtags': [], 'id': '3511510130787749851', 'is_covered': False, 'is_ranked_comment': False, 'mentions': [], 'private_reply_status': 0, 'share_enabled': False, 'text': 'We are both dropping big videos together November 30th 👀', 'text_translation': 'We are both dropping big videos together November 30th 👀', 'type': 1, 'user': {'fbid_v2': 17841402202464771, 'full_name': 'MrBeast', 'id': '2278169415', 'is_private': False, 'is_unpublished': False, 'is_verified': True, 'profile_pic_id': '1765328607101572916', 'profile_pic_url': 'https://scontent-vie1-1.cdninstagram.com/v/t51.2885-19/31077884_211593632905749_1394765701385814016_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-vie1-1.cdninstagram.com&_nc_cat=1&_nc_ohc=4EWS8DciaJMQ7kNvgEje49k&_nc_gid=687e876a6c9c4f5aae96d224cf62ff56&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYDwZba45YlQtmAMia_8X8On34jyAR6zBlUyGWuGrVUqqw&oe=6779530F&_nc_sid=b41fef', 'username': 'mrbeast'}, 'user_id': '2278169415'}, 'caption_is_edited': False, 'carousel_media': [{'carousel_parent_id': '3511510130787749851_2278169415', 'commerciality_status': 'not_commercial', 'explore_pivot_grid': False, 'fb_user_tags': {'in': []}, 'featured_products': [], 'id': '3511510122801906360', 'image_versions': {'items': [{'height': 1800, 'url': 'https://scontent-vie1-1.cdninstagram.com/v/t51.29350-15/468618718_1105623314294222_3860806756476331846_n.jpg?se=7&stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-vie1-1.cdninstagram.com&_nc_cat=1&_nc_ohc=zbtn94fEOK0Q7kNvgHV0NUb&_nc_gid=687e876a6c9c4f5aae96d224cf62ff56&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzUxMTUxMDEyMjgwMTkwNjM2MA%3D%3D.3-ccb7-5&oh=00_AYANZTIO4_Uq0QzyTkZgXZNyB8Sn8G5k_7ilABwvEGRpQw&oe=67794BD2&_nc_sid=b41fef', 'width': 1440}, {'height': 600, 'url': 'https://scontent-vie1-1.cdninstagram.com/v/t51.29350-15/468618718_1105623314294222_3860806756476331846_n.jpg?stp=dst-jpg_e35_p480x480_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-vie1-1.cdninstagram.com&_nc_cat=1&_nc_ohc=zbtn94fEOK0Q7kNvgHV0NUb&_nc_gid=687e876a6c9c4f5aae96d224cf62ff56&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzUxMTUxMDEyMjgwMTkwNjM2MA%3D%3D.3-ccb7-5&oh=00_AYAME222SOsjv4XaNyZpxP7hQ0FBj9muYCvLPbjBs0-kSQ&oe=67794BD2&_nc_sid=b41fef', 'width': 480}]}, 'is_video': False, 'location': None, 'media_name': 'album_item', 'media_type': 1, 'original_height': 1800, 'original_width': 1440, 'product_suggestions': [], 'product_type': 'carousel_item', 'sharing_friction_info': {'bloks_app_url': None, 'sharing_friction_payload': None, 'should_have_sharing_friction': False}, 'shop_routing_user_id': None, 'sponsor_tags': [], 'tagged_users': [{'position': [0.6791277259, 0.453271028], 'show_category_of_user': False, 'user': {'full_name': 'Cristiano Ronaldo', 'id': '173560420', 'is_private': False, 'is_verified': True, 'profile_pic_id': '2821570366679261765', 'profile_pic_url': 'https://scontent-vie1-1.cdninstagram.com/v/t51.2885-19/278931269_360124899498969_9006978846103417088_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-vie1-1.cdninstagram.com&_nc_cat=1&_nc_ohc=5d8jJnmZvZEQ7kNvgEmxxQo&_nc_gid=687e876a6c9c4f5aae96d224cf62ff56&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYARBRuhPMXkfv089WcAnqK83dysfC5jRwPig8A_29xGXQ&oe=6779660E&_nc_sid=b41fef', 'username': 'cristiano'}, 'x': 0.6791277259, 'y': 0.453271028}], 'taken_at': 1732824648, 'taken_at_ts': 1732824648, 'thumbnail_url': 'https://scontent-vie1-1.cdninstagram.com/v/t51.29350-15/468618718_1105623314294222_3860806756476331846_n.jpg?se=7&stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx ...
#                                                       0
# 0     b'{"data":{"count":12,"items":[{"boost_unavail...
# 1     b'null,"can_modify_carousel":false,"can_reply"...
# 2     b'd_at_utc":1732824650,"did_report_as_spam":fa...
# 3     b'false,"mentions":[],"private_reply_status":0...
# 4     b'h \xf0\x9f\x91\x80","text_translation":"We a...
# ...                                                 ...
# 2322  b'e_pic_url":"https://scontent-vie1-1.cdninsta...
# 2323  b'g_e0_s150x150_tt6&_nc_ht=scontent-vie1-1.cdn...
# 2324  b'd224cf62ff56&edm=ABmJApABAAAA&ccb=7-5&oh=00_...
# 2325  b'":"mrbeast"}},"pagination_token":"Ik1IBB8pBB...
# 2326  b'4ZFWUrVwhbAR0RAFsxRj5EHFIBWUZtXi1JRhVTAF46VB...
#
# [2327 rows x 1 columns]

# %%
import requests

url = "https://instagram-scraper-api2.p.rapidapi.com/v1/comments"

querystring = {"code_or_id_or_url":"173560420"}

headers = {
	"x-rapidapi-key": "04edcb85a3mshac913eab2bf3075p184839jsn4e30538b9195",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
df2=pd.DataFrame(response)
df2
# Out:
# {'data': {'additional_data': {'caption': {'content_type': 'comment', 'created_at': 1313425101, 'created_at_for_fb_app': 1313425101, 'created_at_utc': 1313425101, 'did_report_as_spam': False, 'hashtags': [], 'id': '17854592143055023', 'is_covered': False, 'is_created_by_media_owner': True, 'is_ranked_comment': False, 'mentions': [], 'private_reply_status': 0, 'share_enabled': False, 'text': 'Blarney stoneす！', 'type': 1, 'user': {'fbid_v2': 17841401650660110, 'full_name': 'Aya Okari', 'id': '7095022', 'is_private': False, 'is_unpublished': False, 'is_verified': False, 'profile_pic_id': '2123913338047236706', 'profile_pic_url': 'https://scontent-lis1-1.cdninstagram.com/v/t51.2885-19/67442439_525376574871355_5501016369237327872_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-lis1-1.cdninstagram.com&_nc_cat=107&_nc_ohc=9IWFZJEKOfoQ7kNvgEXDalr&_nc_gid=e987a35ebd8043db955e82ec9813801f&edm=AD93TDoBAAAA&ccb=7-5&oh=00_AYB7vCNfimNkt1EGH3UNPaNn0EQ3Ixvcro1w3Xk-xZ459g&oe=67795D66&_nc_sid=87e5dd', 'username': '19790222_ao'}, 'user_id': '7095022'}, 'caption_is_edited': False, 'comment_cover_pos': 'bottom', 'comment_filter_param': 'no_filter', 'comment_likes_enabled': True, 'media_header_display': 'none', 'quick_response_emojis': [{'unicode': '❤️'}, {'unicode': '🙌'}, {'unicode': '🔥'}, {'unicode': '👏'}, {'unicode': '😢'}, {'unicode': '😍'}, {'unicode': '😮'}, {'unicode': '😂'}]}, 'count': 12, 'items': [{'comment_like_count': 0, 'content_type': 'comment', 'created_at': 1731494298, 'created_at_for_fb_app': 1731494298, 'created_at_utc': 1731494298, 'did_report_as_spam': False, 'has_liked': False, 'has_liked_comment': False, 'has_translation': True, 'hashtags': [], 'id': '18062414794775559', 'inline_composer_display_condition': 'never', 'is_covered': False, 'is_pinned': False, 'is_ranked_comment': False, 'like_count': 0, 'mentions': [], 'other_preview_users': [], 'preview_child_comments': [], 'private_reply_status': 0, 'share_enabled': False, 'text': 'هلا', 'type': 0, 'user': {'fbid_v2': 17841418428813807, 'full_name': '', 'id': '18430462293', 'is_mentionable': True, 'is_private': False, 'is_verified': False, 'latest_reel_media': 0, 'profile_pic_id': '3467824665334956253', 'profile_pic_url': 'https://scontent-lis1-1.cdninstagram.com/v/t51.2885-19/461335220_3933984706831120_6013581066308131776_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-lis1-1.cdninstagram.com&_nc_cat=104&_nc_ohc=yRBulT0M7RYQ7kNvgGnx9zw&_nc_gid=e987a35ebd8043db955e82ec9813801f&edm=AD93TDoBAAAA&ccb=7-5&oh=00_AYBhR6NlwPZBdymrNJtq6xw2fiEQcthAOwv57RCgcFfCRQ&oe=677969CB&_nc_sid=87e5dd', 'username': 'ziad_osman_111'}, 'user_id': '18430462293'}, {'comment_like_count': 0, 'content_type': 'comment', 'created_at': 1569440104, 'created_at_for_fb_app': 1569440104, 'created_at_utc': 1569440104, 'did_report_as_spam': False, 'has_liked': False, 'has_liked_comment': False, 'hashtags': [], 'id': '17854564027562599', 'inline_composer_display_condition': 'never', 'is_covered': False, 'is_pinned': False, 'is_ranked_comment': False, 'like_count': 0, 'mentions': [], 'other_preview_users': [], 'preview_child_comments': [], 'private_reply_status': 0, 'share_enabled': False, 'text': 'nice!!', 'type': 0, 'user': {'fbid_v2': 17841421350289245, 'full_name': 'Akash Kadam', 'id': '21193967676', 'is_mentionable': True, 'is_private': True, 'is_verified': False, 'profile_pic_id': '2140930209380838678', 'profile_pic_url': 'https://scontent-lis1-1.cdninstagram.com/v/t51.2885-19/70025764_1642944929173556_1349478780237774848_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-lis1-1.cdninstagram.com&_nc_cat=108&_nc_ohc=ObFKmTsK7jUQ7kNvgHWOU1R&_nc_gid=e987a35ebd8043db955e82ec9813801f&edm=AD93TDoBAAAA&ccb=7-5&oh=00_AYDnorJiWmRg-vfBd7lbpIPRVqvzo1ZvrO8cCDoNATxuRg&oe=67797675&_nc_sid=87e5dd', 'username': 'akash_kadam_75'}, 'user_id': '21193967676'}, {'comment_like_count': 0, 'content_type': 'comment', 'created_at': 1482518526, 'created_at_for_fb_app': 1482518526, 'created_at_utc': 1482518526, 'did_report_as_spam': False,  ...
#                                                      0
# 0    b'{"data":{"additional_data":{"caption":{"cont...
# 1    b'ted_at_utc":1313425101,"did_report_as_spam":...
# 2    b'_owner":true,"is_ranked_comment":false,"ment...
# 3    b',"type":1,"user":{"fbid_v2":1784140165066011...
# 4    b'is_verified":false,"profile_pic_id":"2123913...
# ..                                                 ...
# 122  b'z_Fli-hyJjgsSfvUE7Mxi18HQ&oe=677963B7&_nc_si...
# 123  b'ion_token":"HE1lBBsTFxtJfVZDUThYA0cBVhJuLUAG...
# 124  b'Nh4aC1c-ACwxHjVaKl8dHAsDHh8oBzQERy0EESdEAgQy...
# 125  b'AQNNDUUhBAIXNn05Qz0RBwIrHQ0oOxMzFg1PI24_RzsY...
# 126   b'DEhUKlAKZx1XB1AdRAVKBEB9RwlGUk8dfToVOFsdWgg"}'
#
# [127 rows x 1 columns]

# %%
import requests

url = "https://instagram-scraper-api2.p.rapidapi.com/v1.2/posts"

querystring = {"username_or_id_or_url":"dasoham_"}

headers = {
	"x-rapidapi-key": "04edcb85a3mshac913eab2bf3075p184839jsn4e30538b9195",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json()['data'])
df=pd.DataFrame(response)
df
# Out:
# {'count': 12, 'items': [{'boost_unavailable_identifier': None, 'boost_unavailable_reason': None, 'boost_unavailable_reason_v2': None, 'can_modify_carousel': True, 'can_reply': False, 'can_reshare': True, 'can_save': True, 'caption': {'created_at': 1735571363, 'created_at_utc': 1735571363, 'did_report_as_spam': False, 'hashtags': [], 'id': '3534550609741694286', 'is_covered': False, 'is_ranked_comment': False, 'mentions': [], 'private_reply_status': 0, 'share_enabled': False, 'text': '2024 dump ♥️🥹🫶🏻\n\n What an year it has been and nothing could have been possible without your incredible support ✨🙏\n\nEnvisioning great work and greater times for 2025 🔥📈', 'type': 1, 'user': {'fbid_v2': 17841403987356337, 'full_name': 'दासोहम', 'id': '4050700911', 'is_private': False, 'is_unpublished': False, 'is_verified': False, 'profile_pic_id': '3407687957116226061', 'profile_pic_url': 'https://instagram.fiev22-1.fna.fbcdn.net/v/t51.2885-19/449874139_995314375514068_7422192099522323440_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=instagram.fiev22-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=eZLYCpqed6gQ7kNvgF8q3am&_nc_gid=4c36edb7c4354e938c285e5e658b46ad&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYA8HNN8GhMiRP9vaIyZsXSqn1THKe_XXfiGFI6pxwWUyw&oe=677998F7&_nc_sid=b41fef', 'username': 'dasoham_'}, 'user_id': '4050700911'}, 'caption_is_edited': True, 'carousel_media': [{'carousel_parent_id': '3534550609741694286_4050700911', 'commerciality_status': 'not_commercial', 'explore_pivot_grid': False, 'fb_user_tags': {'in': []}, 'featured_products': [], 'id': '3534550595917236575', 'image_versions': {'items': [{'height': 1800, 'url': 'https://instagram.fiev22-1.fna.fbcdn.net/v/t51.29350-15/472189025_1129315122145787_6724848624205714018_n.jpg?se=7&stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=instagram.fiev22-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=qIbT7_eGT_QQ7kNvgEvxgCQ&_nc_gid=4c36edb7c4354e938c285e5e658b46ad&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzUzNDU1MDU5NTkxNzIzNjU3NQ%3D%3D.3-ccb7-5&oh=00_AYD35l_t7bpvj84edoGtX0bQjwiNIzEAhj92kLdAu4mQ4w&oe=67798DE9&_nc_sid=b41fef', 'width': 1440}, {'height': 600, 'url': 'https://instagram.fiev22-1.fna.fbcdn.net/v/t51.29350-15/472189025_1129315122145787_6724848624205714018_n.jpg?stp=dst-jpg_e35_p480x480_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=instagram.fiev22-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=qIbT7_eGT_QQ7kNvgEvxgCQ&_nc_gid=4c36edb7c4354e938c285e5e658b46ad&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzUzNDU1MDU5NTkxNzIzNjU3NQ%3D%3D.3-ccb7-5&oh=00_AYBoJauC2u2DXKypOsA4EW66Eb4uWG-n47XMIuRy0Kqe3A&oe=67798DE9&_nc_sid=b41fef', 'width': 480}]}, 'is_video': False, 'location': None, 'media_name': 'album_item', 'media_type': 1, 'original_height': 1800, 'original_width': 1440, 'product_suggestions': [], 'product_type': 'carousel_item', 'sharing_friction_info': {'bloks_app_url': None, 'sharing_friction_payload': None, 'should_have_sharing_friction': False}, 'shop_routing_user_id': None, 'sponsor_tags': [], 'tagged_users': [], 'taken_at': 1735571287, 'taken_at_ts': 1735571287, 'thumbnail_url': 'https://instagram.fiev22-1.fna.fbcdn.net/v/t51.29350-15/472189025_1129315122145787_6724848624205714018_n.jpg?se=7&stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=instagram.fiev22-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=qIbT7_eGT_QQ7kNvgEvxgCQ&_nc_gid=4c36edb7c4354e938c285e5e658b46ad&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzUzNDU1MDU5NTkxNzIzNjU3NQ%3D%3D.3-ccb7-5&oh=00_AYD35l_t7bpvj84edoGtX0bQjwiNIzEAhj92kLdAu4mQ4w&oe=67798DE9&_nc_sid=b41fef', 'video_sticker_locales': []}, {'carousel_parent_id': '3534550609741694286_4050700911', 'commerciality_status': 'not_commercial', 'explore_pivot_grid': False, 'fb_user_tags': {'in': []}, 'featured_products': [], 'id': '3534550595917223648', 'image_versions': {'items': [{'height': 1800, 'url': 'https://instagram.fiev22-1.fna.fbcdn.net/v/t51. ...
#                                                       0
# 0     b'{"data":{"count":12,"items":[{"boost_unavail...
# 1     b'null,"can_modify_carousel":true,"can_reply":...
# 2     b'_at_utc":1735571363,"did_report_as_spam":fal...
# 3     b'alse,"mentions":[],"private_reply_status":0,...
# 4     b'een and nothing could have been possible wit...
# ...                                                 ...
# 1944  b'26061","profile_pic_url":"https://instagram....
# 1945  b'.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=inst...
# 1946  b'db7c4354e938c285e5e658b46ad&edm=ABmJApABAAAA...
# 1947  b'1fef","username":"dasoham_"}},"pagination_to...
# 1948  b'BVAFINEnMDSBEbBh4ZFWUrVwhbAR0RAFsxQj5JHFQBUU...
#
# [1949 rows x 1 columns]

# %%
import requests

url = "https://instagram-scraper-api2.p.rapidapi.com/v1/comments"

querystring = {"code_or_id_or_url":"DENPw1-S0VO"}

headers = {
	"x-rapidapi-key": "04edcb85a3mshac913eab2bf3075p184839jsn4e30538b9195",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

comments = response.json().get('comments', [])
text = response.json().get('data', {}).get('additional_data', {}).get('caption', {}).get('text', '')
for comment in comments:
	print(comment.get('text', ''))



print(response.json())

print(text)
# Out:
# {'data': {'additional_data': {'caption': {'content_type': 'comment', 'created_at': 1735571363, 'created_at_for_fb_app': 1735571363, 'created_at_utc': 1735571363, 'did_report_as_spam': False, 'hashtags': [], 'id': '17956289996749610', 'is_covered': False, 'is_created_by_media_owner': True, 'is_ranked_comment': False, 'mentions': [], 'private_reply_status': 0, 'share_enabled': False, 'text': '2024 dump ♥️🥹🫶🏻\n\n What an year it has been and nothing could have been possible without your incredible support ✨🙏\n\nEnvisioning great work and greater times for 2025 🔥📈', 'type': 1, 'user': {'fbid_v2': 17841403987356337, 'full_name': 'दासोहम', 'id': '4050700911', 'is_private': False, 'is_unpublished': False, 'is_verified': False, 'profile_pic_id': '3407687957116226061', 'profile_pic_url': 'https://scontent-hel3-1.cdninstagram.com/v/t51.2885-19/449874139_995314375514068_7422192099522323440_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-hel3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=eZLYCpqed6gQ7kNvgHRTRzj&_nc_gid=1176660f1044476f92b1e2dd8c469047&edm=AD93TDoBAAAA&ccb=7-5&oh=00_AYCqmnEbIn6qbYyhEltXHQ9HygrESMDn6Z9-rrLDS0jvOg&oe=677998F7&_nc_sid=87e5dd', 'username': 'dasoham_'}, 'user_id': '4050700911'}, 'caption_is_edited': True, 'comment_cover_pos': 'bottom', 'comment_filter_param': 'no_filter', 'comment_likes_enabled': True, 'media_header_display': 'none', 'quick_response_emojis': [{'unicode': '❤️'}, {'unicode': '🙌'}, {'unicode': '🔥'}, {'unicode': '👏'}, {'unicode': '😢'}, {'unicode': '😍'}, {'unicode': '😮'}, {'unicode': '😂'}]}, 'count': 15, 'items': [{'comment_like_count': 0, 'content_type': 'comment', 'created_at': 1735635752, 'created_at_for_fb_app': 1735635752, 'created_at_utc': 1735635752, 'did_report_as_spam': False, 'has_liked': False, 'has_liked_comment': False, 'hashtags': [], 'id': '18162581539326323', 'inline_composer_display_condition': 'never', 'is_covered': False, 'is_pinned': False, 'is_ranked_comment': False, 'like_count': 0, 'mentions': [], 'other_preview_users': [], 'preview_child_comments': [], 'private_reply_status': 0, 'share_enabled': False, 'text': '12th slide 🥹🫶🏻', 'type': 0, 'user': {'fbid_v2': 17841449132682034, 'full_name': 'Garvit Sharma', 'id': '48976277756', 'is_mentionable': True, 'is_private': True, 'is_verified': False, 'profile_pic_id': '3499977654265616896', 'profile_pic_url': 'https://scontent-hel3-1.cdninstagram.com/v/t51.2885-19/466982875_3637124663099876_8214583260005133480_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-hel3-1.cdninstagram.com&_nc_cat=108&_nc_ohc=nVADgRMy2rkQ7kNvgEBVEl7&_nc_gid=1176660f1044476f92b1e2dd8c469047&edm=AD93TDoBAAAA&ccb=7-5&oh=00_AYBhp6AkOucDuF_nG_NSQhSO2iYK_jBr-J6zXihVmVn3hg&oe=67797520&_nc_sid=87e5dd', 'username': 'garvitities'}, 'user_id': '48976277756'}, {'comment_like_count': 0, 'content_type': 'comment', 'created_at': 1735635285, 'created_at_for_fb_app': 1735635285, 'created_at_utc': 1735635285, 'did_report_as_spam': False, 'has_liked': False, 'has_liked_comment': False, 'has_translation': True, 'hashtags': [], 'id': '18044517185470169', 'inline_composer_display_condition': 'never', 'is_covered': False, 'is_pinned': False, 'is_ranked_comment': False, 'like_count': 0, 'mentions': [], 'other_preview_users': [], 'preview_child_comments': [], 'private_reply_status': 0, 'share_enabled': False, 'text': 'Theen Bhai theeno Tabhai ❤️', 'type': 0, 'user': {'fbid_v2': 17841408547061767, 'full_name': 'Aashutosh Aashutosh', 'id': '8414140902', 'is_mentionable': True, 'is_private': False, 'is_verified': False, 'latest_reel_media': 0, 'profile_pic_id': '3374838821576114972', 'profile_pic_url': 'https://scontent-hel3-1.cdninstagram.com/v/t51.2885-19/446114004_3767478496830571_9216725964350089040_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-hel3-1.cdninstagram.com&_nc_cat=107&_nc_ohc=HpdgCn3K1MQQ7kNvgGT-JPe&_nc_gid=1176660f1044476f92b1e2dd8c469047&edm=AD93TDoBAAAA&ccb=7-5&oh=00_AYAPjMGorT37i6eaEetSg3JOtVtg0HYTl8g2kL8MabMUBw&oe=6779797A&_nc_sid=87e5dd', 'username': 'okey_aashu'}, ' ...
# 2024 dump ♥️🥹🫶🏻
#
#  What an year it has been and nothing could have been possible without your incredible support ✨🙏
#
# Envisioning great work and greater times for 2025 🔥📈
