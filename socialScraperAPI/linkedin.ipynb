# %%
import requests
import pandas as pd

url = "https://linkedin-api8.p.rapidapi.com/get-profile-posts"

querystring = {"username":"adamselipsky"}

headers = {
	"x-rapidapi-key": "04edcb85a3mshac913eab2bf3075p184839jsn4e30538b9195",
	"x-rapidapi-host": "linkedin-api8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())

df = pd.DataFrame(response.json()['data'])
df.head()
# Out:
# {'success': True, 'message': '', 'data': [{'text': 'Thanks for the conversation, Todd Bishop. Coming back to lead Amazon Web Services (AWS) was an incredible opportunity. I’m so proud of the team, all the capabilities we developed for customers, and the business milestones achieved. AWS is better positioned than anyone to expand possibilities for customers going forward. Leaving things in good hands with Matt Garman and the team.', 'totalReactionCount': 2091, 'likeCount': 1856, 'appreciationCount': 19, 'empathyCount': 97, 'InterestCount': 7, 'praiseCount': 112, 'commentsCount': 72, 'repostsCount': 49, 'postUrl': 'https://www.linkedin.com/feed/update/urn:li:activity:7202377267048570880/', 'postedAt': '7mo', 'postedDate': '2024-05-31 18:35:54.163 +0000 UTC', 'postedDateTimestamp': 1717180554163, 'urn': '7202377267048570880', 'author': {'id': 11848598, 'firstName': 'Adam', 'lastName': 'Selipsky', 'headline': 'Former CEO at Amazon Web Services (AWS). Former President and CEO at Tableau.'
# ...

# %%
df['text'][1:10].values
# Out:
# array(['After almost 15 combined years at AWS, I am going to be moving on. It has been a true privilege to help lead this business from pre-revenue to $100B annualized revenue. I’m humbled by the many customers who have said they wouldn’t be what they are without AWS, thankful to our many partners, and grateful to my passionate and innovative teammates. AWS will be in great hands with Matt and the incredible leadership team. I’m looking forward to taking some time off with family, while taking the opportunity to think about my next adventure!',
# ...

# %%
import requests
import pandas as pd

url = "https://linkedin-api8.p.rapidapi.com/get-profile-comments"

querystring = {"username":"adamselipsky"}

headers = {
	"x-rapidapi-key": "04edcb85a3mshac913eab2bf3075p184839jsn4e30538b9195",
	"x-rapidapi-host": "linkedin-api8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())

df1 = pd.DataFrame(response.json()['data'])
df1.head()
# Out:
# {'success': True, 'message': '', 'data': [{'highlightedComments': ['Thanks for having me on, Brian! Enjoyed talking about all things AWS, including our continued growth and AI innovation for customers.'], 'highlightedCommentsActivityCounts': [{'text': 'Thanks for having me on, Brian! Enjoyed talking about all things AWS, including our continued growth and AI innovation for customers.', 'totalReactionCount': 5, 'likeCount': 5}], 'text': "New Opening Bid podcast drop now on Yahoo Finance\n\nAmazon AWS CEO Adam Selipsky steps up to the 🎙️:\n\n💪AWS now at a $100 billion plus annualized sales run rate.\n\n📈The big opportunity coming for AWS.\n\n😀Inside Amazon’s AI plans.\n\n📜The Andy Jassy interview.\n\n🤖 NVIDIA's importance to the tech landscape.\n\nFull watch ➡ https://lnkd.in/epS9BqnU", 'commentUrl': 'https://www.linkedin.com/feed/update/urn:li:activity:7192135651801149440?commentUrn=urn%3Ali%3Acomment%3A%28activity%3A7192135651801149440%2C7192673365445283841%29&dashCommentUrn=urn%3Ali
# ...

# %%
df1['highlightedComments'][0:10].values
# Out:
# array([list(['Thanks for having me on, Brian! Enjoyed talking about all things AWS, including our continued growth and AI innovation for customers.']),
#        list(["Congrats to you and the Snowflake team, Sridhar. We are proud that Snowflake chose AWS's ML infrastructure to train Arctic models."]),
#        list(['Great to see this Varun. Well done to you and team on the launch of Rocket Logic – Synopsis. Thrilled to have Amazon Bedrock and the AWS cloud power your new generative AI tool!']),
#        list(['Happy Amaversary. Great learnings. Cheers to 10 years!\n\xa0']),
#        list(['We’re really excited as well, Tom! Going to be great for customers.']),
#        list(['Great to have dinner with you and the other incredible start-ups in Paris! The innovation there is all so exciting!']),
#        list(['So glad to have you as host for the meeting, Shaown! Great job.']),
# ...
